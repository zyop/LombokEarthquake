# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import matplotlib as mpl

# %%
pwd
# Out:
# 'C:\\Users\\Owner\\Desktop\\Project Final Exam'

# %%
df = pd.read_csv(r"D:\a.csv")
df.head()
# Out:
#    ContryCrisisID Snapshot date         SSID              Site Name  Latitude  \
# 0             165     9/30/2018  KLBRBB-0044       DUDUK ATAS RT. 2  -8.50848
# 1             165     9/30/2018  KLBRBB-0046       LAPANGAN GALAKSI  -8.52966
# 2             165     9/30/2018  KLBRBB-0047  POSKO 1 BANGKET ORONG  -8.51772
# 3             165     9/30/2018  KLBRBB-0086       POSKO KUBUR BARU  -8.52721
# 4             165     9/30/2018  KLBRBB-0087  DUSUN DUDUK ATAS RT 1  -8.50841
#
#    Longitude          City City Code   Districts  Districts Code  \
# 0  116.06700  LOMBOK BARAT   IDN5201  BATU LAYAR             NaN
# 1  116.07843  LOMBOK BARAT   IDN5201  BATU LAYAR             NaN
# 2  116.08082  LOMBOK BARAT   IDN5201  BATU LAYAR             NaN
# 3  116.08026  LOMBOK BARAT   IDN5201  BATU LAYAR             NaN
# 4  116.06713  LOMBOK BARAT   IDN5201  BATU LAYAR             NaN
#
#          City.1  City Code.1  House Damage  Total People  Male  Female
# ...

# %%
df['Male'].sum()
# Out:
# 231513

# %%
df['Female'].sum()
# Out:
# 200502

# %%
df['House Damage'].sum()
# Out:
# 130299.0

# %%
df['Total People'].sum()
# Out:
# 432015

# %%
plt.figure(figsize = (40,10))
sns.lmplot("House Damage", "Total People", data = df);

# %%
a = df.sort_values('House Damage', ascending = False)
b = a.head (n=10)
#b = a.head (n=5)
b
# Out:
#       ContryCrisisID Snapshot date         SSID                     Site Name  \
# 1945             165     9/30/2018  KLUTPP-1739                      MENGGALA
# 1566             165     9/30/2018  KLUTGB-1730              DUSUN LOANGSAWAK
# 1595             165     9/30/2018  KLUTGG-0736                 DUSUN KERAKAS
# 1570             165     9/30/2018  KLUTGB-1831                     LUK BARAT
# 915              165     9/30/2018  KLTMPB-2446                BATU YANG DAYA
# 912              165     9/30/2018  KLTMPB-1972  MASJID BAITUL RAHIM BATUYANG
# 2500             165     9/30/2018  SMWBBB-0263              DUSUN BRANG BATU
# 1912             165     9/30/2018  KLUTPP-0132                  TELUK KOMBAL
# 276              165     9/30/2018  KLBRGK-1326                 KEKAIT TAEBAH
# 1590             165     9/30/2018  KLUTGG-0728                   TELOK GERAN
#
#       Latitude  Longitude           City City Code      Districts  \
# ...

# %%
plt.figure(figsize = (40,10))
sns.lmplot("Latitude", "Longitude", data = b);

# %%
plt.rcParams.update({'font.size': 8})
plt.figure (figsize=(15,10))
sns.barplot ("Site Name", "House Damage", data=b);

# %%
plt.figure (figsize=(15,10))
sns.boxplot ("Districts", "House Damage", data=b);

# %%
plt.figure (figsize=(15,10))
sns.boxplot ("City", "House Damage", data=b);

# %%
p = df.sort_values('Total People', ascending = False)
q = p.head (n=10)
q
# Out:
#       ContryCrisisID Snapshot date         SSID  \
# 2260             165     9/30/2018  MTRMCS-0819
# 1566             165     9/30/2018  KLUTGB-1730
# 1595             165     9/30/2018  KLUTGG-0736
# 1945             165     9/30/2018  KLUTPP-1739
# 1959             165     9/30/2018  KLUTPP-2322
# 1901             165     9/30/2018  KLUTPP-0001
# 1624             165     9/30/2018  KLUTGG-1923
# 912              165     9/30/2018  KLTMPB-1972
# 915              165     9/30/2018  KLTMPB-2446
# 1590             165     9/30/2018  KLUTGG-0728
#
#                           Site Name  Latitude  Longitude          City  \
# 2260  LINGKUNGAN SAPTA MARGA GEBANG  -8.59618  116.11801       MATARAM
# 1566               DUSUN LOANGSAWAK  -8.38007  116.18306  LOMBOK UTARA
# 1595                  DUSUN KERAKAS  -8.31654  116.19624  LOMBOK UTARA
# 1945                       MENGGALA  -8.42814  116.08986  LOMBOK UTARA
# 1959                POLSEK PEMENANG  -8.40916  116.10090  LOMBOK UTARA
# ...

# %%
plt.figure(figsize = (40,10))
sns.lmplot("Total People", "House Damage", data = q);

# %%
plt.rcParams.update({'font.size': 30})
plt.figure (figsize=(25,10))
sns.barplot ("Site Name", "Total People", data=q);

# %%
plt.figure (figsize=(15,10))
sns.boxplot ("Districts", "Total People", data=q);

# %%
plt.figure (figsize=(15,10))
sns.boxplot ("City", "Total People", data=q);

# %%
r = df.sort_values('Male', ascending = False)
s = r.head (n=10)
s
# Out:
#       ContryCrisisID Snapshot date         SSID  \
# 2260             165     9/30/2018  MTRMCS-0819
# 1566             165     9/30/2018  KLUTGB-1730
# 1595             165     9/30/2018  KLUTGG-0736
# 1945             165     9/30/2018  KLUTPP-1739
# 1959             165     9/30/2018  KLUTPP-2322
# 1901             165     9/30/2018  KLUTPP-0001
# 1624             165     9/30/2018  KLUTGG-1923
# 912              165     9/30/2018  KLTMPB-1972
# 915              165     9/30/2018  KLTMPB-2446
# 1590             165     9/30/2018  KLUTGG-0728
#
#                           Site Name  Latitude  Longitude          City  \
# 2260  LINGKUNGAN SAPTA MARGA GEBANG  -8.59618  116.11801       MATARAM
# 1566               DUSUN LOANGSAWAK  -8.38007  116.18306  LOMBOK UTARA
# 1595                  DUSUN KERAKAS  -8.31654  116.19624  LOMBOK UTARA
# 1945                       MENGGALA  -8.42814  116.08986  LOMBOK UTARA
# 1959                POLSEK PEMENANG  -8.40916  116.10090  LOMBOK UTARA
# ...

# %%
plt.figure (figsize=(25,10))
sns.barplot ("Site Name", "Male", data=s);

# %%
t = df.sort_values('Female', ascending = False)
u = t.head (n=10)
u
# Out:
#       ContryCrisisID Snapshot date         SSID  \
# 2260             165     9/30/2018  MTRMCS-0819
# 1566             165     9/30/2018  KLUTGB-1730
# 1595             165     9/30/2018  KLUTGG-0736
# 1945             165     9/30/2018  KLUTPP-1739
# 1959             165     9/30/2018  KLUTPP-2322
# 1901             165     9/30/2018  KLUTPP-0001
# 1624             165     9/30/2018  KLUTGG-1923
# 912              165     9/30/2018  KLTMPB-1972
# 915              165     9/30/2018  KLTMPB-2446
# 1590             165     9/30/2018  KLUTGG-0728
#
#                           Site Name  Latitude  Longitude          City  \
# 2260  LINGKUNGAN SAPTA MARGA GEBANG  -8.59618  116.11801       MATARAM
# 1566               DUSUN LOANGSAWAK  -8.38007  116.18306  LOMBOK UTARA
# 1595                  DUSUN KERAKAS  -8.31654  116.19624  LOMBOK UTARA
# 1945                       MENGGALA  -8.42814  116.08986  LOMBOK UTARA
# 1959                POLSEK PEMENANG  -8.40916  116.10090  LOMBOK UTARA
# ...

# %%
plt.figure (figsize=(30,20))
sns.barplot ("Site Name", "Female", data=u);

# %%
plt.figure (figsize=(30,20))
sns.barplot ("Site Name", , data=u);
